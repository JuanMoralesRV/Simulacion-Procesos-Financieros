# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.stats import norm

# Parámetros base
ticker = 'SPY'
data = yf.download(ticker, start='2022-01-01', end='2025-10-15', progress=False)['Close']
S0 = data.iloc[-1]
r = 0.0411
T = 100 / 365
K = 680

# Cálculo de volatilidad histórica
daily_returns = data.pct_change().dropna()
sigma = daily_returns.std() * np.sqrt(252)

# Fórmulas de Black-Scholes
d1 = (np.log(S0 / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
d2 = d1 - sigma * np.sqrt(T)

call_black_scholes = S0 * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
put_black_scholes = K * np.exp(-r * T) * norm.cdf(-d2) - S0 * norm.cdf(-d1)

print(f"Black-Scholes Call: {call_black_scholes}")
print(f"Black-Scholes Put: {put_black_scholes}")
# Out:
# C:\Users\juanm\AppData\Local\Temp\ipykernel_34256\1800288609.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start='2022-01-01', end='2025-10-15', progress=False)['Close']
# Black-Scholes Call: Ticker
# SPY    20.746663
# Name: 2025-10-14 00:00:00, dtype: float64
# Black-Scholes Put: Ticker
# SPY    30.902645
# Name: 2025-10-14 00:00:00, dtype: float64
